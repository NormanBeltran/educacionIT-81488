# %% [markdown]
# # Clase 1 - Python para Análisis de Datos
#
# ## Python inicial
#
# ![imagen.png](attachment:f69f2b8b-cc48-4655-b606-270b0b3fb1ad.png)

# %%
print("Hola Mundo")
print("Bienvenidos!")
# Out:
# Hola Mundo
# Bienvenidos!

# %%
a = 1000
print("A = ", a)
# Out:
# A =  1000

# %%
a = True + True

# %%
a
# Out:
# 2

# %% [markdown]
# ### Objetos
#
# - Punteros y referencias: comportamiento diferente entre estructuras complejas y variables de tipo basico

# %%
l1 = [1,2,3]
l2 = l1
l3 = [1,2,3]

# %%
l1[0] = 999

# %%
l1
# Out:
# [999, 2, 3]

# %%
l2
# Out:
# [999, 2, 3]

# %%
l2[1] = 888

# %%
l1
# Out:
# [999, 888, 3]

# %%
l3
# Out:
# [1, 2, 3]

# %%
id(l1)
# Out:
# 1906493392640

# %%
id(l2)
# Out:
# 1906493392640

# %%
id(l3)
# Out:
# 1906493394752

# %%
a = 1111

# %%
type(a)
# Out:
# int

# %%
a = "Hola"

# %%
type(a)
# Out:
# str

# %%
v1 = 1
v2 = v1
v3 = 1

# %%
v1 = 999

# %%
v2
# Out:
# 1

# %%
id(v2)
# Out:
# 140716405959096

# %%
id(v3)
# Out:
# 140716405959096
